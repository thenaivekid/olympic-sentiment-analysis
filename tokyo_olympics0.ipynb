# %%
from google.colab import drive
drive.mount('content/')
# Out:
# Mounted at content/

# %%
# !pip install transformers
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.2/7.2 MB 57.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 268.8/268.8 kB 30.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 91.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 54.6 MB/s eta 0:00:00
# ...

# %%
import pandas as pd
import numpy as np

# %%
PATH = '/content/content/MyDrive/tokyo_olympics/Olympics_Tokyo_tweets.csv'
df = pd.read_csv(PATH)
df.head()
# Out:
# <ipython-input-3-552ddda81261>:2: DtypeWarning: Columns (0,4,5,6,10) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(PATH)
#                     id                                               text  \
# 0  1419334065375924227  Rejected sports for the 2020 Olympics include ...
# 1  1419334059424043009  Why is the Team USA men basketball team playin...
# 2  1419334056161030146  @my_hive_away I'm watching kayaking on the Oly...
# 3  1419334052876795905  While girls her age are still trying to figuri...
# 4  1419334052180594699   @omensfromeden patty mills is at the Olympics???
#
#   user_screen_name                user_location retweet_count favorited  \
# 0      tbelmontedu                   New Jersey             0     False
# 1      silverchasm                  Lynwood, CA             0     False
# 2    cshaw12897514                          NaN             0     False
# ...

# %%
df.nunique()
# Out:
# id                  307231
# text                301886
# user_screen_name    191124
# user_location        58678
# retweet_count          328
# favorited                5
# favorite_count         956
# user_description    170448
# user_created_at     190935
# user_followers       33725
# user_friends         19567
# date                135218
# language                 1
# dtype: int64

# %%
df.shape
# Out:
# (312825, 13)

# %%
from transformers import pipeline

sent_pipeline = pipeline("sentiment-analysis", model='finiteautomata/bertweet-base-sentiment-analysis')
# Out:
# ...
# emoji is not installed, thus not converting emoticons or emojis into text. Install emoji: pip3 install emoji==0.6.0
# Xformers is not installed correctly. If you want to use memory_efficient_attention to accelerate training use the following command to install Xformers
# pip install xformers.

# %%
# pred = sent_pipeline(df['text'][0])
# label = str(pred[0]['label'])
# score = float(pred[0]['score'])
# label, score
# Out:
# ('NEG', 0.7984506487846375)

# %%
# labels = []
# scores = []
# SAVE_FILE_PATH = '/content/content/MyDrive/tokyo_olympics/sentiment2.csv'

# %%
# for i in range(0, 311):
#   for item in df['text'][(i*1000):(i+1)*1000]:
#       pred = sent_pipeline(item)
#       labels.append(str(pred[0]['label']))
#       scores.append(float(pred[0]['score']))
#       print('.', end='')
#   sent_df = {'labels': labels, 'score': scores}
#   sent_df = pd.DataFrame(sent_df)
#   sent_df.to_csv(SAVE_FILE_PATH)
#   print(f"{i} done \n")


# for i in range((31200-1), (312825-1)):
#     pred = sent_pipeline(df['text'][i])
#     labels.append(str(pred[0]['label']))
#     scores.append(float(pred[0]['score']))
# sent_df = {'labels': labels, 'score': scores}
# sent_df = pd.DataFrame(sent_df)
# sent_df.to_csv(SAVE_FILE_PATH)
# print("saved all")
# Out:
# ......................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................
# ...

# %%
new_df.to_csv('/content/content/MyDrive/tokyo_olympics/final_data.csv')

# %%
df = pd.read_csv('/content/content/MyDrive/tokyo_olympics/final_data.csv')
df.head()
# Out:
#    Unnamed: 0                                               text  \
# 0           0  Rejected sports for the 2020 Olympics include ...
# 1           1  Why is the Team USA men basketball team playin...
# 2           2  @my_hive_away I'm watching kayaking on the Oly...
# 3           3  While girls her age are still trying to figuri...
# 4           4   @omensfromeden patty mills is at the Olympics???
#
#                  user_location labels     score
# 0                   New Jersey    NEG  0.798451
# 1                  Lynwood, CA    NEG  0.980415
# 2                          NaN    POS  0.985244
# 3                United States    NEU  0.967262
# 4  hozier.tamino.florence.etc.    NEU  0.971178
